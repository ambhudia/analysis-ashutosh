# %% [markdown]
# # Discharge Vs Salinity in SoG

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import cmocean
import pickle
import time
import datetime
import ffmpeg
from salishsea_tools import viz_tools
from salishsea_tools import geo_tools
from salishsea_tools import grid_tools
from salishsea_tools import utilities
# %matplotlib inline

# %%
loadtxt = open('Fraser_flow', 'r')
fraser_discharge = np.loadtxt(loadtxt, usecols =(0,1,2,3), delimiter = ' ')

# Load data from text file into xarray
years, months, days = fraser_discharge[:,0].astype(int), fraser_discharge[:,1].astype(int), fraser_discharge[:,2].astype(int)
discharge_data = fraser_discharge[:,3]

time_array = np.array([])
for date in np.arange(days.shape[0]):
    time_array = np.append(time_array, datetime.datetime(years[date], months[date], days[date]))

data = xr.DataArray(discharge_data, coords = [time_array], dims = ['time'])

# %%
salinity = xr.open_dataset("https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSg3DTracerFields1hV18-06")
times_salinity = salinity.time.sel(time = salinity.time.dt.year.isin([2015,2016,2017,2018])).values.astype('datetime64[s]').astype(datetime.datetime)

# %% [markdown]
# ## Function Definitions

# %%
def load_data(year, path = "/home/abhudia/Desktop/salinity/Raw/{}salinity.pickle",):
    filename= (path).format(str(year))
    unpickle = open(filename, "rb")
    salinity = pickle.load(unpickle)
    times = []
    for time in times_salinity: 
        if time.year == year:
            times.append(time)
    return(times, salinity)

# %%
# gives data and timeseries from discharge data
def give_data_with_time (xarray, year):
    discharge = xarray.loc[xarray['time.year'].isin([year])].values
    times = xarray.loc[xarray['time.year'].isin([year])].time.values.astype('datetime64[D]').astype(datetime.datetime)
    return (times, discharge)

# %% [markdown]
# ## Scratch space

# %%
def average_output(data_array, times, period = 'D'):

    unique, counts = np.unique(np.asarray(times).astype('datetime64[{}]'.format(period)).astype(datetime.datetime), return_counts=True) 
    index = 0; count_so_far = 0; means = np.array([])
    
    for count in counts:
        means = np.append(means,sum(data_array[count_so_far: count_so_far + count])/count)
        count_so_far = count_so_far + count
        
    return means

# %%
salinity2015 = load_data(2015)

# %%
salinity2015[1].shape
# Out:
# (8760, 540, 355)

# %%
averaged_grid = average_output(salinity2015[1], salinity2015[0])

# %%
rshaped = averaged_grid.reshape(365,540,355)

# %%
import ffmpeg
ffmpeg._ffmpeg
# Out:
# <module 'ffmpeg._ffmpeg' from '/home/abhudia/anaconda3/lib/python3.7/site-packages/ffmpeg/_ffmpeg.py'>

# %%
import matplotlib.image as mpimg
writer = animation.FFMpegWriter()
PATH = "ims/{}.png"

def update(i):
    p = PATH.format(str(i))
    #print p
    image = mpimg.imread(p) # images are color images
    plt.gca().clear()
    plt.imshow(image)

ani = animation.FuncAnimation(plt.gcf(), update, range(10), interval = 50, repeat=False)
ani.save('try.mp4', writer = writer)
plt.show()
# Out:
# <matplotlib.animation.FFMpegWriter object at 0x7f98c8263240>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-f346db9da46d> in <module>
#      12
#      13 ani = animation.FuncAnimation(plt.gcf(), update, range(10), interval = 50, repeat=False)
# ---> 14 ani.save('try.mp4', writer = writer)
#      15 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1164                           "animation.")
#    1165                 rcParams['savefig.bbox'] = None
# -> 1166             with writer.saving(self._fig, filename, dpi):
#    1167                 for anim in all_anim:
#    1168                     # Clear the initial frame
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     226         '''
#     227         # This particular sequence is what contextlib.contextmanager wants
# --> 228         self.setup(fig, outfile, dpi, *args, **kwargs)
#     229         try:
#     230             yield self
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in setup(self, fig, outfile, dpi)
#     340         # Run here so that grab_frame() can write the data to a pipe. This
#     341         # eliminates the need for temp files.
# --> 342         self._run()
#     343
#     344     def _run(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _run(self)
#     352                                       stdout=output, stderr=output,
#     353                                       stdin=subprocess.PIPE,
# --> 354                                       creationflags=subprocess_creation_flags)
#     355
#     356     def finish(self):
#
# ~/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     767                                 c2pread, c2pwrite,
#     768                                 errread, errwrite,
# --> 769                                 restore_signals, start_new_session)
#     770         except:
#     771             # Cleanup if the child failed starting.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1514                         if errno_num == errno.ENOENT:
#    1515                             err_msg += ': ' + repr(err_filename)
# -> 1516                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1517                 raise child_exception_type(err_msg)
#    1518
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ffmpeg': 'ffmpeg'

# %%
ims = []



for i in range(10):
    fig = plt.figure(figsize = (10,10))
    plt.subplot(2,1,1)
    plt.pcolormesh(rshaped[i], cmap = 'Reds')
    plt.colorbar()
    plt.subplot(2,1,2)
    discharge = give_data_with_time(data, 2015)
    plt.plot(discharge[0], discharge[1])
    plt.vlines(discharge[0][i], 0, 8000)
    plt.savefig('ims/{}.png'.format(str(i)))

# %%
ani = animation.ArtistAnimation(fig, ims, interval = 50, blit= True)
# Out:
# Traceback (most recent call last):
#   File "/home/abhudia/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "/home/abhudia/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py", line 999, in _start
#     self._init_draw()
#   File "/home/abhudia/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py", line 1535, in _init_draw
#     for artist in f:
# TypeError: 'Figure' object is not iterable

# %%
import matplotlib.animation as animation

# %%
discharge = give_data_with_time(data, 2015)

# %%
ani = animation.ArtistAnimation(fig, image_list, interval = 50, blit = True)
# Out:
# Traceback (most recent call last):
#   File "/home/abhudia/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "/home/abhudia/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py", line 999, in _start
#     self._init_draw()
#   File "/home/abhudia/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py", line 1535, in _init_draw
#     for artist in f:
# TypeError: 'PngImageFile' object is not iterable

# %%
ims[0]
# Out:
# <_io.TextIOWrapper name='ims/0.png' mode='r' encoding='UTF-8'>

# %%
plt.imshow(image_list[0])
