# %% [markdown]
# # This Notebook Provides Examples of Usage of the plotting tools in mohid_viz.py

# %%
import mohid_viz

# %% [markdown]
# # You may have used a constant field to force MOHID using the .dat configuration. To create .hdf5 equivalents of these, use the mohid_diagnostic_tools/constant_field.ipynb notebook to generate the forcing files you need

# %% [markdown]
# ## Animation of Surface Thickness and Surface Concentration with Scopes

# %%
# xr_path - path to output Lagrangian netcdf file
# currents_path - path to currents forcing file used
# winds_path - path to winds forcing file used
# outfile path - path+name of output .mp4 file (with added .mp4 extension)
mohid_viz.plot_thick_conc(xr_path = '../results/vvl_testing/vvl_ssh2/Lagrangian_vvl_ssh2.nc',
                currents_path = '../data/constant_currents/currents_west_above2_north_below2.hdf5',
                winds_path = '../data/zerowinds.hdf5',
                outfile_path = 'vvl_ssh2.mp4')
# Out:
# /home/abhudia/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1334: MatplotlibDeprecationWarning:
# box-forced
#   "2.2", "box-forced", obj_type="keyword argument")
# /home/abhudia/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# /home/abhudia/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1028: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %% [markdown]
# ## Produce plot of 3D oil concentration

# %%
# xr_path - path to output Lagrangian netcdf file
# outfile path - path+name of output .png image (with added .mp4 extension)
# title - title to put on the image
mohid_viz.conc_heatmap(oilpath = '/home/abhudia/viz_test/vvl/Lagrangian_SOGa_01dec17_MF0_1000m3_7days_unrotated_smalldt_hi.nc', 
                       outfile = 'hi_tide.png', 
                       title = '(release at high tide)')
# Out:
# Loading...  23% (37 of 156) |########                           |ETA:   0:00:25
